# %%
# !wget https://s3.amazonaws.com/nyc-tlc/misc/taxi+_zone_lookup.csv
# Out:
# --2026-01-14 09:05:58--  https://s3.amazonaws.com/nyc-tlc/misc/taxi+_zone_lookup.csv
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.153.206, 16.182.73.216, 52.217.201.176, ...
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.153.206|:443... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2026-01-14 09:05:59 ERROR 403: Forbidden.

# %%
import pandas as pd

url = "https://d37ci6vzurychx.cloudfront.net/misc/taxi_zone_lookup.csv"
zones = pd.read_csv(url)
print(zones.head())
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
zones.to_sql(name='zones', con=engine, if_exists='replace')
# Out:
# 265
